# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fig,myAX = plt.subplots()
fig.set_size_inches(17,11)


scopeData = pd.read_csv('temp.CSV',delimiter=',',names=['a','b','c','d','e','f'])
xvals = scopeData['d']
yvals = scopeData['e']
start = int(float(scopeData.loc[2,'b']))
a = plt.plot(xvals[start:],yvals[start:])
scopeData = pd.read_csv('F0000CH2.CSV',delimiter=',',names=['a','b','c','d','e','f'])
xvals = scopeData['d']
yvals = scopeData['e']
b = myAX.plot(xvals[start:],yvals[start:])
plt.show(b)
